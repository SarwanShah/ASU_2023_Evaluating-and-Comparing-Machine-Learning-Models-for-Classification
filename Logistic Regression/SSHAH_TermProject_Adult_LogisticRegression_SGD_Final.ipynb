# %% [markdown]
# # Importing Data and Libraries

# %%
# !pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.10/dist-packages (0.0.3)

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold

import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn

import copy
import time

torch.manual_seed(42)
np.random.seed(42)

# %%
adult_uci = fetch_ucirepo(id=2)

dataset = adult_uci.data.original
dataset['labels'] = dataset.income

for i in range(len(dataset.labels)):
  if (dataset.labels[i] == '<=50K.'):
    dataset.labels[i] = '<=50K'
  elif (dataset.labels[i] == '>50K.'):
    dataset.labels[i] = '>50K'

dataset = dataset.drop(columns=['income'])

print(dataset.labels[4881-1])
print(dataset.info())
# Out:
# <ipython-input-20-7dc5b1c285a9>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.labels[i] = '<=50K'
# <ipython-input-20-7dc5b1c285a9>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.labels[i] = '>50K'
# >50K
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       47879 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      47876 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  48568 non-null  object
#  14  labels          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB
# None

# %% [markdown]
# # Pre-processing Data: Cleaning, Equalizing, and LabelEncoding

# %%
missing = dataset.isnull().sum()
duplicates = dataset.duplicated().sum()

dataset = dataset.dropna()
dataset = dataset.drop_duplicates()

print("Missing values removed:\n" + str(missing))
print("\nDuplicates removed:", duplicates)
print(dataset.info())
# Out:
# Missing values removed:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# labels            0
# dtype: int64
#
# Duplicates removed: 0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47573 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             47573 non-null  int64
#  1   workclass       47573 non-null  object
#  2   fnlwgt          47573 non-null  int64
#  3   education       47573 non-null  object
#  4   education-num   47573 non-null  int64
#  5   marital-status  47573 non-null  object
#  6   occupation      47573 non-null  object
#  7   relationship    47573 non-null  object
#  8   race            47573 non-null  object
#  9   sex             47573 non-null  object
#  10  capital-gain    47573 non-null  int64
#  11  capital-loss    47573 non-null  int64
#  12  hours-per-week  47573 non-null  int64
#  13  native-country  47573 non-null  object
#  14  labels          47573 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.8+ MB
# None

# %%
labelCount = 0
data = dataset
numerical = dataset.select_dtypes(include=['int64']).columns
categoricalColumns = dataset.select_dtypes(include=['object']).columns
categoricalColumns = [column for column in categoricalColumns if column != 'labels']
for column in categoricalColumns:
    labelCount += len(dataset[f'{column}'].unique())
    one_hot_encoded = pd.get_dummies(dataset[column], prefix=f'{column}_')
    data = pd.concat([data, one_hot_encoded], axis=1)

data = data.drop(columns=categoricalColumns)
data['labels'] = dataset['labels']

print(data.info(), labelCount, len(categoricalColumns), len(numerical))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47573 entries, 0 to 48841
# Columns: 109 entries, age to native-country__Yugoslavia
# dtypes: int64(6), object(1), uint8(102)
# memory usage: 7.5+ MB
# None 102 8 6

# %%
classCount = data['labels'].value_counts()
minClassCount = classCount.min()
print(classCount)
newData = pd.DataFrame(columns=data.columns)

for label in classCount.index:
      classSamples = data[data['labels'] == label]
      newSamples = classSamples.sample(minClassCount)
      newData = pd.concat([newData, newSamples])

data = newData
print(data.info())
# Out:
# <=50K    36038
# >50K     11535
# Name: labels, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23070 entries, 20550 to 46291
# Columns: 109 entries, age to native-country__Yugoslavia
# dtypes: object(109)
# memory usage: 19.4+ MB
# None

# %%
featuresRaw = data.drop('labels', axis=1)
labelsRaw = data.labels

labelMapping = {}

labelEncoder = LabelEncoder()
labelsEncoded = labelEncoder.fit_transform(labelsRaw)

for class_ in labelEncoder.classes_:
  encoding = labelEncoder.transform([class_])[0]
  labelMapping[encoding] = class_

labels = labelsEncoded
print(labelMapping)
# Out:
# {0: '<=50K', 1: '>50K'}

# %% [markdown]
# # Splitting Data

# %%
X_train, X_test, y_train, y_test = train_test_split(featuresRaw, labels, test_size=0.3, random_state=42)

trainScaler = StandardScaler()
X_train = trainScaler.fit_transform(X_train)
X_test = trainScaler.transform(X_test)

X_train_df = pd.DataFrame(X_train, columns=featuresRaw.columns)
X_test_df = pd.DataFrame(X_test, columns=featuresRaw.columns)

X_train_df.head()

X_data = np.array(featuresRaw)
y_data = np.array(labels)

# %% [markdown]
# # Model Construction and Training

# %%
class LogisticRegression(nn.Module):
  def __init__(self, num_features, l2=0.0):
    super(LogisticRegression, self).__init__()
    self.layer1 = nn.Linear(num_features, 1)
    self.sig = nn.Sigmoid()
    self.l2 = l2


  def forward(self, x):
    out0 = self.layer1(x)
    out1 = self.sig(out0)
    return out1

# %%
def resetWeights(model):
    for layer in model.children():
        if isinstance(layer, nn.Linear):
            layer.reset_parameters()

def trainModelKFold(model, epochs, lossFn, optimizer, X, y, decisionThreshold=0.5, k=1):
    trainAcc, testAcc = np.zeros(epochs), np.zeros(epochs)
    trainErr, testErr = np.zeros(epochs), np.zeros(epochs)
    trainLoss, testLoss = np.zeros(epochs), np.zeros(epochs)

    kf = KFold(n_splits=k, shuffle=True, random_state=42)

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        trainScaler = StandardScaler()
        X_train = trainScaler.fit_transform(X_train)
        X_test = trainScaler.transform(X_test)

        X_train_tensor = torch.tensor(X_train).float()
        X_test_tensor = torch.tensor(X_test).float()
        y_train_tensor = torch.tensor(y_train).float()
        y_test_tensor = torch.tensor(y_test).float()

        resetWeights(model)
        for epoch in range(epochs):
            output = model(X_train_tensor)
            loss = lossFn(output.squeeze(), y_train_tensor)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            with torch.no_grad():
                trainLoss[epoch] += loss.item()
                trainPredictions = (np.array(output.flatten()) > decisionThreshold).astype(int)
                trainError = np.mean(trainPredictions != np.array(y_train_tensor).astype(int))


                output = model(X_test_tensor)
                loss = lossFn(output.squeeze(), y_test_tensor)

                testLoss[epoch] += loss.item()
                testPredictions = (np.array(output.flatten()) > decisionThreshold).astype(int)
                testError = np.mean(testPredictions != np.array(y_test_tensor).astype(int))

                trainErr[epoch] += trainError.item()
                testErr[epoch] += testError.item()
                trainAcc[epoch] += 1 - trainError.item()
                testAcc[epoch] += 1 - testError.item()

    avg_trainAcc = trainAcc/k
    avg_testAcc = testAcc/k
    avg_trainErr = trainErr/k
    avg_testErr = testErr/k
    avg_trainLoss = trainLoss/k
    avg_testLoss = testLoss/k

    return avg_trainAcc, avg_testAcc, avg_trainErr, avg_testErr, avg_trainLoss, avg_testLoss

def trainModel(model, epochs, lossFn, optimizer, X_train, X_test, y_train, y_test, decisionThreshold=0.5):
    trainAcc, testAcc = [], []
    trainErr, testErr = [], []
    trainLoss, testLoss = [], []

    resetWeights(model)
    for epoch in range(epochs):
        output = model(X_train)
        loss = lossFn(output.squeeze(), y_train)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        with torch.no_grad():
            trainLoss.append(loss.item())
            trainPredictions = (np.array(output.flatten()) > decisionThreshold).astype(int)
            trainError = np.mean(trainPredictions != np.array(y_train).astype(int))


            output = model(X_test)
            loss = lossFn(output.squeeze(), y_test)

            testLoss.append(loss.item())
            testPredictions = (np.array(output.flatten()) > decisionThreshold).astype(int)
            testError = np.mean(testPredictions != np.array(y_test).astype(int))

            trainErr.append(trainError.item())
            testErr.append(testError.item())
            trainAcc.append(1 - trainError.item())
            testAcc.append(1 - testError.item())

    return trainAcc, testAcc, trainErr, testErr, trainLoss, testLoss


X_train_tensor = torch.tensor(X_train).float()
y_train_tensor = torch.tensor(y_train).float()
X_test_tensor = torch.tensor(X_test).float()
y_test_tensor = torch.tensor(y_test).float()

# %% [markdown]
# # Grid Search Analysis

# %%
epochs_list = [50, 100, 500, 1000]
learning_rates = [1, 0.1, 0.01, 0.001]
momentums = [0, 0.5, 0.9, 0.99]
lambdas = [0, 0.001, 0.01, 0.1, 1]
trainedModels = []

num_features = len(X_train_df.columns)
lossFn = nn.BCELoss()

for lambda_ in lambdas:
  model = LogisticRegression(num_features, l2=lambda_)
  for momentum in momentums:
    for lr in learning_rates:
        optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=model.l2)
        for epochs in epochs_list:
          startTime = time.time()
          trainAcc, testAcc, trainErr, testErr, trainLoss, testLoss = trainModelKFold(
              model,
              epochs,
              lossFn,
              optimizer,
              X_data,
              y_data,
              k=5,
          )
          trainingTime = time.time() - startTime
          trainedModels.append({ 'model': copy.deepcopy(model),
                                'hyperparameters': {'epochs': epochs, 'lr': lr, 'momentum': momentum, 'lambda': lambda_ },
                                'trainingStats': { 'testAcc': testAcc[-1], 'trainAcc': trainAcc[-1],
                                                    'testError': testErr[-1], 'trainError': trainErr[-1],
                                                    'testLoss': testLoss[-1], 'trainLoss': trainLoss[-1] },
                                'trainingTime': trainingTime
                                })
          print(f'Completed epochs, lr, momentum, lambda, test error: {epochs}, {lr}, {momentum}, {lambda_}, --- {testAcc[-1]}')
# Out:
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0, 0, --- 0.8144343302990897
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0, 0, --- 0.8159947984395318
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0, 0, --- 0.8187689640225401
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0, 0, --- 0.8191157347204161
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0, 0, --- 0.8013437364542696
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0, 0, --- 0.8079757260511486
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0, 0, --- 0.8145210229735588
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0, 0, --- 0.8159514521022974
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0, 0, --- 0.7395752058951018
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0, 0, --- 0.7727785002167317
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0, 0, --- 0.8025574338968356
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0, 0, --- 0.8078890333766797
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0, 0, --- 0.5281751192024273
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0, 0, --- 0.570307758994365
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0, 0, --- 0.7392284351972258
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0, 0, --- 0.7636324230602514
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.5, 0, --- 0.8161248374512354
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.5, 0, --- 0.8182054616384914
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.5, 0, --- 0.8191157347204161
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.5, 0, --- 0.8192024273948851
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.5, 0, --- 0.8077589943649762
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.5, 0, --- 0.8101430429128739
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.5, 0, --- 0.8159081057650628
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.5, 0, --- 0.8179453836150845
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.5, 0, --- 0.7704377980060685
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.5, 0, --- 0.7804941482444734
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.5, 0, --- 0.8075856090160383
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.5, 0, --- 0.8109666233203294
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.5, 0, --- 0.5872128305158214
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.5, 0, --- 0.6539661898569571
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.5, 0, --- 0.7690940615517988
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.5, 0, --- 0.7858690940615518
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.9, 0, --- 0.818942349371478
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.9, 0, --- 0.8195925444299956
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.9, 0, --- 0.8191590810576506
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.9, 0, --- 0.8191590810576506
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.9, 0, --- 0.8155179887299523
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.9, 0, --- 0.8163415691374081
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.9, 0, --- 0.8188123103597744
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.9, 0, --- 0.8191157347204161
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.9, 0, --- 0.801560468140442
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.9, 0, --- 0.8075856090160383
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.9, 0, --- 0.8141742522756827
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.9, 0, --- 0.8159081057650628
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.9, 0, --- 0.7391850888599915
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.9, 0, --- 0.7681404421326399
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.9, 0, --- 0.8021239705244907
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.9, 0, --- 0.8075422626788036
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.99, 0, --- 0.7672301690507152
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.99, 0, --- 0.7912006935413957
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.99, 0, --- 0.8179453836150845
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.99, 0, --- 0.8188556566970091
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.99, 0, --- 0.7890333766796704
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.99, 0, --- 0.7978326831382748
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.99, 0, --- 0.8177719982661464
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.99, 0, --- 0.8193324664065885
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.99, 0, --- 0.8099263112267012
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.99, 0, --- 0.8086692674469006
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.99, 0, --- 0.8181187689640226
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.99, 0, --- 0.8192024273948851
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.99, 0, --- 0.7880797572605115
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.99, 0, --- 0.8020372778500218
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.99, 0, --- 0.8152145643693108
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.99, 0, --- 0.8162548764629388
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0, 0.001, --- 0.8140875596012137
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0, 0.001, --- 0.8156046814044213
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0, 0.001, --- 0.818682271348071
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0, 0.001, --- 0.8189856957087125
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0, 0.001, --- 0.8004768097095795
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0, 0.001, --- 0.807845687039445
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0, 0.001, --- 0.8140875596012137
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0, 0.001, --- 0.8156046814044213
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0, 0.001, --- 0.7387082791504118
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0, 0.001, --- 0.7687472908539228
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0, 0.001, --- 0.8007802340702209
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0, 0.001, --- 0.8079323797139141
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0, 0.001, --- 0.5726918075422627
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0, 0.001, --- 0.5967056783701777
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0, 0.001, --- 0.7283485045513653
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0, 0.001, --- 0.7639358474208929
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.5, 0.001, --- 0.8159514521022974
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.5, 0.001, --- 0.8176853055916776
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.5, 0.001, --- 0.8189856957087125
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.5, 0.001, --- 0.8188990030342437
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.5, 0.001, --- 0.8078023407022107
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.5, 0.001, --- 0.8112267013437364
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.5, 0.001, --- 0.8155179887299523
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.5, 0.001, --- 0.8178586909406155
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.5, 0.001, --- 0.7707845687039445
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.5, 0.001, --- 0.7840918942349372
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.5, 0.001, --- 0.8076723016905071
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.5, 0.001, --- 0.8106198526224533
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.5, 0.001, --- 0.5870827915041179
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.5, 0.001, --- 0.6933246640658863
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.5, 0.001, --- 0.7657997399219767
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.5, 0.001, --- 0.7818378846987429
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.9, 0.001, --- 0.818508885999133
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.9, 0.001, --- 0.8188990030342437
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.9, 0.001, --- 0.8188990030342437
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.9, 0.001, --- 0.8188990030342437
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.9, 0.001, --- 0.8153879497182487
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.9, 0.001, --- 0.8158647594278283
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.9, 0.001, --- 0.8188990030342435
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.9, 0.001, --- 0.8189856957087125
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.9, 0.001, --- 0.8009102730819245
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.9, 0.001, --- 0.807845687039445
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.9, 0.001, --- 0.8145210229735588
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.9, 0.001, --- 0.8156480277416559
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.9, 0.001, --- 0.7262678803641093
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.9, 0.001, --- 0.7704377980060684
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.9, 0.001, --- 0.8010836584308626
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.9, 0.001, --- 0.806892067620286
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.99, 0.001, --- 0.7767230169050715
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.99, 0.001, --- 0.7895535327264845
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.99, 0.001, --- 0.8173385348938016
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.99, 0.001, --- 0.8188556566970091
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.99, 0.001, --- 0.7858257477243173
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.99, 0.001, --- 0.7995231902904205
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.99, 0.001, --- 0.8181187689640226
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.99, 0.001, --- 0.8192457737321197
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.99, 0.001, --- 0.8091894234937147
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.99, 0.001, --- 0.8105765062852189
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.99, 0.001, --- 0.8188990030342437
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.99, 0.001, --- 0.8188556566970092
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.99, 0.001, --- 0.7886866059817945
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.99, 0.001, --- 0.803337667967057
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.99, 0.001, --- 0.8150411790203729
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.99, 0.001, --- 0.8159947984395318
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0, 0.01, --- 0.8130472475075857
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0, 0.01, --- 0.8143042912873861
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0, 0.01, --- 0.8151712180320763
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0, 0.01, --- 0.8151712180320763
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0, 0.01, --- 0.8028175119202426
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0, 0.01, --- 0.8079323797139143
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0, 0.01, --- 0.8130472475075855
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0, 0.01, --- 0.8142175986129171
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0, 0.01, --- 0.7355006501950585
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0, 0.01, --- 0.7696142175986129
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0, 0.01, --- 0.8006935413957521
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0, 0.01, --- 0.806805374945817
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0, 0.01, --- 0.5485478977026441
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0, 0.01, --- 0.5765496315561334
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0, 0.01, --- 0.7437364542696143
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0, 0.01, --- 0.7698309492847855
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.5, 0.01, --- 0.8146510619852622
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.5, 0.01, --- 0.8152145643693108
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.5, 0.01, --- 0.8151712180320763
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.5, 0.01, --- 0.8151712180320763
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.5, 0.01, --- 0.8084091894234937
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.5, 0.01, --- 0.8103164282618118
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.5, 0.01, --- 0.8142609449501517
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.5, 0.01, --- 0.8151712180320763
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.5, 0.01, --- 0.7662332032943218
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.5, 0.01, --- 0.7842219332466407
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.5, 0.01, --- 0.806805374945817
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.5, 0.01, --- 0.8096228868660598
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.5, 0.01, --- 0.5098396185522323
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.5, 0.01, --- 0.6578240138708278
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.5, 0.01, --- 0.7664932813177285
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.5, 0.01, --- 0.7849588209796272
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.9, 0.01, --- 0.8144776766363243
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.9, 0.01, --- 0.8150411790203729
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.9, 0.01, --- 0.8151712180320763
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.9, 0.01, --- 0.8151712180320763
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.9, 0.01, --- 0.8146510619852622
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.9, 0.01, --- 0.8146077156480278
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.9, 0.01, --- 0.8151712180320763
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.9, 0.01, --- 0.8151712180320763
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.9, 0.01, --- 0.8006068487212831
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.9, 0.01, --- 0.8086259211096662
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.9, 0.01, --- 0.8131339401820545
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.9, 0.01, --- 0.8142609449501517
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.9, 0.01, --- 0.7315994798439532
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.9, 0.01, --- 0.7712613784135242
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.9, 0.01, --- 0.8020806241872561
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.9, 0.01, --- 0.8092761161681838
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.99, 0.01, --- 0.7739488513220634
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.99, 0.01, --- 0.7825314260944951
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.99, 0.01, --- 0.8135240572171651
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.99, 0.01, --- 0.8150845253576072
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.99, 0.01, --- 0.7870827915041179
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.99, 0.01, --- 0.7985695708712613
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.99, 0.01, --- 0.8154746423927179
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.99, 0.01, --- 0.8150411790203729
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.99, 0.01, --- 0.8103164282618118
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.99, 0.01, --- 0.8081057650628523
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.99, 0.01, --- 0.8150411790203729
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.99, 0.01, --- 0.8155179887299523
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.99, 0.01, --- 0.7869960988296489
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.99, 0.01, --- 0.8019072388383182
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.99, 0.01, --- 0.8147811009969658
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.99, 0.01, --- 0.8143909839618552
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0, 0.1, --- 0.7998266146510621
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0, 0.1, --- 0.8056350238404855
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0, 0.1, --- 0.7346770697876029
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0, 0.1, --- 0.7750325097529259
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0, 0.1, --- 0.8023407022106632
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0, 0.1, --- 0.8061551798872995
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0, 0.1, --- 0.5014304291287386
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0, 0.1, --- 0.553272648461205
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0, 0.1, --- 0.7444733420026008
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0, 0.1, --- 0.7698309492847855
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.5, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.5, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.5, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.5, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.5, 0.1, --- 0.8071087993064585
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.5, 0.1, --- 0.8073255309926312
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.5, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.5, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.5, 0.1, --- 0.769960988296489
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.5, 0.1, --- 0.7859991330732553
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.5, 0.1, --- 0.8070221066319896
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.5, 0.1, --- 0.807498916341569
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.5, 0.1, --- 0.6014737754659732
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.5, 0.1, --- 0.6471174685739055
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.5, 0.1, --- 0.7763762462071956
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.5, 0.1, --- 0.7873428695275249
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.9, 0.1, --- 0.8036410923276984
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.9, 0.1, --- 0.8071521456436932
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.9, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.9, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.9, 0.1, --- 0.806111833550065
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.9, 0.1, --- 0.8072821846553966
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.9, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.9, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.9, 0.1, --- 0.8012570437798006
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.9, 0.1, --- 0.8067620286085827
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.9, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.9, 0.1, --- 0.8074122236671002
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.9, 0.1, --- 0.7344169917641958
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.9, 0.1, --- 0.7749458170784568
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.9, 0.1, --- 0.8025140875596012
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.9, 0.1, --- 0.8054182921543129
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.99, 0.1, --- 0.7692674469007368
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.99, 0.1, --- 0.7788469874295622
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.99, 0.1, --- 0.8055483311660165
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.99, 0.1, --- 0.807498916341569
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.99, 0.1, --- 0.7931946250541829
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.99, 0.1, --- 0.7852188990030343
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.99, 0.1, --- 0.8062418725617686
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.99, 0.1, --- 0.8068487212830517
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.99, 0.1, --- 0.8042912873862159
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.99, 0.1, --- 0.7680104031209363
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.99, 0.1, --- 0.8067620286085825
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.99, 0.1, --- 0.8074989163415692
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.99, 0.1, --- 0.7878630255743388
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.99, 0.1, --- 0.8033810143042913
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.99, 0.1, --- 0.8070221066319896
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.99, 0.1, --- 0.8070221066319896
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0, 1, --- 0.8028608582574771
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0, 1, --- 0.8041179020372778
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0, 1, --- 0.7967923710446467
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0, 1, --- 0.7950585175552665
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0, 1, --- 0.7926311226701344
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0, 1, --- 0.7926744690073688
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0, 1, --- 0.7587776332899872
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0, 1, --- 0.7805808409189423
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0, 1, --- 0.7926744690073688
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0, 1, --- 0.7926744690073688
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0, 1, --- 0.5148244473342003
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0, 1, --- 0.5922843519722584
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0, 1, --- 0.7509752925877764
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0, 1, --- 0.7790637191157347
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.5, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.5, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.5, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.5, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.5, 1, --- 0.7926744690073688
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.5, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.5, 1, --- 0.7926744690073688
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.5, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.5, 1, --- 0.7836584308625921
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.5, 1, --- 0.7905938448201127
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.5, 1, --- 0.7926744690073688
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.5, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.5, 1, --- 0.6120936280884266
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.5, 1, --- 0.664109232769831
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.5, 1, --- 0.7791504117902036
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.5, 1, --- 0.7904204594711748
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.9, 1, --- 0.7982228001733853
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.9, 1, --- 0.7927611616818379
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.9, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.9, 1, --- 0.7926744690073688
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.9, 1, --- 0.7906371911573471
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.9, 1, --- 0.7928478543563069
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.9, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.9, 1, --- 0.7926744690073688
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.9, 1, --- 0.7930645860424794
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.9, 1, --- 0.7931079323797139
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.9, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.9, 1, --- 0.7927178153446033
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.9, 1, --- 0.753012570437798
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.9, 1, --- 0.7800606848721283
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.9, 1, --- 0.7928912006935412
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.9, 1, --- 0.7926744690073688
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.99, 1, --- 0.6206328565236238
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.99, 1, --- 0.7587342869527525
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.99, 1, --- 0.793888166449935
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.99, 1, --- 0.7933246640658865
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.99, 1, --- 0.7701777199826615
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.99, 1, --- 0.7626354573038577
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.99, 1, --- 0.7976159514521023
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.99, 1, --- 0.793281317728652
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.99, 1, --- 0.7266146510619852
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.99, 1, --- 0.754659731252709
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.99, 1, --- 0.7921976592977893
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.99, 1, --- 0.7924143909839618
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.99, 1, --- 0.7800606848721283
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.99, 1, --- 0.7809709579540529
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.99, 1, --- 0.7872995231902904
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.99, 1, --- 0.7933680104031209

# %% [markdown]
# # Finding the best model that maximizes accuracy using ROC curve:

# %%
def findOptimalThresholdForModelAcc(model, X_test_tensor, y_test_tensor):
  with torch.no_grad(): output = model(X_test_tensor)
  _, _, thresholds = roc_curve(y_test_tensor.detach().numpy(), output.detach().numpy().flatten(), pos_label=1)
  optimalAcc = None
  optimalThreshold = None

  for threshold in thresholds:
    testPredictions = (np.array(output.detach().numpy().flatten()) > threshold).astype(int)
    testAcc = 1 - np.mean(testPredictions != np.array(y_test_tensor).astype(int))
    if (optimalThreshold == None):
      optimalThreshold = threshold
      optimalAcc = testAcc
    elif (testAcc > optimalAcc):
      optimalThreshold = threshold
      optimalAcc = testAcc



  return optimalAcc, optimalThreshold

# %%
globalOptimalModel = None
globalOptimalLoss = None
globalOptimalAcc = None
globalOptimalThreshold = None

for model_ in trainedModels:
    optimalAcc, optimalThreshold = findOptimalThresholdForModelAcc(
        model_['model'],
        X_test_tensor,
        y_test_tensor
    )
    optimalLoss = model_['trainingStats']['testLoss']

    if (globalOptimalLoss == None):
      globalOptimalLoss = optimalLoss
      globalOptimalAcc = optimalAcc
      globalOptimalModel = model_
      globalOptimalThreshold = optimalThreshold
    elif (optimalAcc > globalOptimalAcc):
      globalOptimalLoss = optimalLoss
      globalOptimalAcc = optimalAcc
      globalOptimalModel = model_
      globalOptimalThreshold = optimalThreshold
    elif (optimalAcc == globalOptimalAcc and optimalLoss < globalOptimalLoss):
      globalOptimalLoss = optimalLoss
      globalOptimalAcc = optimalAcc
      globalOptimalModel = model_
      globalOptimalThreshold = optimalThreshold

print(globalOptimalModel)
# Out:
# {'model': LogisticRegression(
#   (layer1): Linear(in_features=108, out_features=1, bias=True)
#   (sig): Sigmoid()
# ), 'hyperparameters': {'epochs': 500, 'lr': 1, 'momentum': 0.99, 'lambda': 0.001}, 'trainingStats': {'testAcc': 0.8173385348938016, 'trainAcc': 0.8206111833550065, 'testError': 0.18266146510619855, 'trainError': 0.17938881664499348, 'testLoss': 0.3909030735492706, 'trainLoss': 0.3845378041267395}, 'trainingTime': 11.974690675735474}

# %%
gModel = globalOptimalModel['model']
with torch.no_grad(): output = gModel(X_test_tensor)
fpr, tpr, thresholds = roc_curve(y_test_tensor.detach().numpy(), output.detach().numpy().flatten(), pos_label=1)
rocAUC = auc(fpr, tpr)

plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(rocAUC))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
gLr = globalOptimalModel['hyperparameters']['lr']
gEpochs = globalOptimalModel['hyperparameters']['epochs']
gMomentum = globalOptimalModel['hyperparameters']['momentum']
gLambda = globalOptimalModel['hyperparameters']['lambda']

index = int(np.where(thresholds == globalOptimalThreshold)[0])
FPR = fpr[index]
TPR = tpr[index]

print(f'Global Optimal Model Hyperparameters: lr={gLr}, epochs={gEpochs}, momentum={gMomentum}, lamda={gLambda}')
print(f'Global Optimal TPR: {TPR}, Global Optimal FPR: {FPR}, Global Optimal Threshold: {globalOptimalThreshold}')
print(f'Global Optimal Acc: {globalOptimalAcc}, Global Optimal Loss: {globalOptimalLoss}')
# Out:
# Global Optimal Model Hyperparameters: lr=1, epochs=500, momentum=0.99, lamda=0.001
# Global Optimal TPR: 0.8731537793223284, Global Optimal FPR: 0.22808535178777392, Global Optimal Threshold: 0.45434075593948364
# Global Optimal Acc: 0.822280017338535, Global Optimal Loss: 0.3909030735492706

# %% [markdown]
# ## Reproducability Test & Visualizing Training Curves

# %%
lr = globalOptimalModel['hyperparameters']['lr']
epochs = globalOptimalModel['hyperparameters']['epochs']
momentum = globalOptimalModel['hyperparameters']['momentum']
lambda_ = globalOptimalModel['hyperparameters']['lambda']

num_features = len(X_train_df.columns)
model = LogisticRegression(num_features, l2=lambda_)
lossFn = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=model.l2)

trainAcc, testAcc, trainErr, testErr, trainLoss, testLoss = trainModelKFold(
    model,
    epochs,
    lossFn,
    optimizer,
    X_data,
    y_data,
    k=5,
)

model.eval()

plt.plot(trainAcc, label='train accuracy')
plt.plot(testAcc, label='test accuracy')
plt.grid(True)
plt.legend()

plt.figure()
plt.plot(trainErr, label='train error')
plt.plot(testErr, label='test error')
plt.grid(True)
plt.legend()

plt.figure()
plt.plot(trainLoss, label='train loss')
plt.plot(testLoss, label='test loss')
plt.grid(True)
plt.legend()

plt.show()


print(f'Train Accuracy: {trainAcc[-1]}, Train Error: {trainErr[-1]}, Train Loss: {trainLoss[-1]}')
print(f'Test Accuracy: {testAcc[-1]}, Test Error: {testErr[-1]}, Test Loss: {testLoss[-1]}')
# Out:
# Train Accuracy: 0.8206328565236237, Train Error: 0.17936714347637622, Train Loss: 0.38440213203430174
# Test Accuracy: 0.818942349371478, Test Error: 0.1810576506285219, Test Loss: 0.3907181978225708

# %%
with torch.no_grad(): output = model(X_test_tensor)
fpr, tpr, thresholds = roc_curve(y_test_tensor.detach().numpy(), output.detach().numpy().flatten(), pos_label=1)
rocAUC = auc(fpr, tpr)

plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(rocAUC))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
optimalAcc, optimalThreshold = findOptimalThresholdForModelAcc(
        model,
        X_test_tensor,
        y_test_tensor,
    )

index = int(np.where(thresholds == optimalThreshold)[0])
FPR = fpr[index]
TPR = tpr[index]

print(f'Global Optimal Model Hyperparameters: lr={lr}, epochs={epochs}, momentum={momentum}, lamda={lambda_}')
print(f'Global Optimal TPR: {TPR}, Global Optimal FPR: {FPR}, Global Optimal Threshold: {optimalThreshold}')
print(f'Global Optimal Acc: {optimalAcc}, Global Optimal Loss: {testLoss[-1]}')
# Out:
# Global Optimal Model Hyperparameters: lr=1, epochs=500, momentum=0.99, lamda=0.001
# Global Optimal TPR: 0.856067187952505, Global Optimal FPR: 0.21366782006920415, Global Optimal Threshold: 0.47602036595344543
# Global Optimal Acc: 0.8212686028030631, Global Optimal Loss: 0.3907181978225708

# %% [markdown]
# # Time Complexity Analysis

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

lambdaValue = 0.001
filteredModels = [modelInfo for modelInfo in trainedModels if modelInfo['hyperparameters']['lambda'] == lambdaValue]

epochsList = [modelInfo['hyperparameters']['epochs'] for modelInfo in filteredModels]
learningRates = [modelInfo['hyperparameters']['lr'] for modelInfo in filteredModels]
momentums = [modelInfo['hyperparameters']['momentum'] for modelInfo in filteredModels]
trainingTimes = [modelInfo['trainingTime'] for modelInfo in filteredModels]

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(epochsList, learningRates, momentums, c=trainingTimes, cmap='viridis', marker='o', s=100)
ax.set_xlabel('Epochs')
ax.set_ylabel('Learning Rate')
ax.set_zlabel('Momentum')
ax.set_title('Training Time Variation with Hyperparameters')
cbar = plt.colorbar(sc)
cbar.set_label('Training Time (seconds)')

plt.show()
