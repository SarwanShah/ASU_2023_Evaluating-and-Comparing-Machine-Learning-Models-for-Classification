# %% [markdown]
# ## Importing Data and Libraries

# %%
# !pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.3-py3-none-any.whl (7.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.3

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold

import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn

import copy
import time

torch.manual_seed(42)
np.random.seed(42)

# %%
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)

data = breast_cancer_wisconsin_diagnostic.data.features
data['labels'] = breast_cancer_wisconsin_diagnostic.data.targets

print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   radius1             569 non-null    float64
#  1   texture1            569 non-null    float64
#  2   perimeter1          569 non-null    float64
#  3   area1               569 non-null    float64
#  4   smoothness1         569 non-null    float64
#  5   compactness1        569 non-null    float64
#  6   concavity1          569 non-null    float64
#  7   concave_points1     569 non-null    float64
#  8   symmetry1           569 non-null    float64
#  9   fractal_dimension1  569 non-null    float64
#  10  radius2             569 non-null    float64
#  11  texture2            569 non-null    float64
#  12  perimeter2          569 non-null    float64
#  13  area2               569 non-null    float64
#  14  smoothness2         569 non-null    float64
#  15  compactness2        569 non-null    float64
#  16  concavity2          569 non-null    float64
#  17  concave_points2     569 non-null    float64
#  18  symmetry2           569 non-null    float64
#  19  fractal_dimension2  569 non-null    float64
#  20  radius3             569 non-null    float64
#  21  texture3            569 non-null    float64
#  22  perimeter3          569 non-null    float64
#  23  area3               569 non-null    float64
#  24  smoothness3         569 non-null    float64
#  25  compactness3        569 non-null    float64
#  26  concavity3          569 non-null    float64
#  27  concave_points3     569 non-null    float64
#  28  symmetry3           569 non-null    float64
#  29  fractal_dimension3  569 non-null    float64
#  30  labels              569 non-null    object
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB
# None
# <ipython-input-5-ae980457afec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['labels'] = breast_cancer_wisconsin_diagnostic.data.targets

# %% [markdown]
# ## Pre-processing Data: Cleaning, Equalizing, and LabelEncoding

# %%
missing = data.isnull().sum()
duplicates = data.duplicated().sum()

data = data.dropna()
data = data.drop_duplicates()

print("Missing values removed:\n" + str(missing))
print("\nDuplicates removed:", duplicates)
# Out:
# Missing values removed:
# radius1               0
# texture1              0
# perimeter1            0
# area1                 0
# smoothness1           0
# compactness1          0
# concavity1            0
# concave_points1       0
# symmetry1             0
# fractal_dimension1    0
# radius2               0
# texture2              0
# perimeter2            0
# area2                 0
# smoothness2           0
# compactness2          0
# concavity2            0
# concave_points2       0
# symmetry2             0
# fractal_dimension2    0
# radius3               0
# texture3              0
# perimeter3            0
# area3                 0
# smoothness3           0
# compactness3          0
# concavity3            0
# concave_points3       0
# symmetry3             0
# fractal_dimension3    0
# labels                0
# dtype: int64
#
# Duplicates removed: 0

# %%
# Balancing the data here to remove the class imbalance. Tried exploring class_weights to address imbalance, but ran into issues with Pytorch.
# Hence used this approach as an alternative

classCount = data['labels'].value_counts()
minClassCount = classCount.min()
newData = pd.DataFrame(columns=data.columns)

for label in classCount.index:
      classSamples = data[data['labels'] == label]
      newSamples = classSamples.sample(minClassCount)
      newData = pd.concat([newData, newSamples])

data = newData
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 424 entries, 395 to 39
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   radius1             424 non-null    float64
#  1   texture1            424 non-null    float64
#  2   perimeter1          424 non-null    float64
#  3   area1               424 non-null    float64
#  4   smoothness1         424 non-null    float64
#  5   compactness1        424 non-null    float64
#  6   concavity1          424 non-null    float64
#  7   concave_points1     424 non-null    float64
#  8   symmetry1           424 non-null    float64
#  9   fractal_dimension1  424 non-null    float64
#  10  radius2             424 non-null    float64
#  11  texture2            424 non-null    float64
#  12  perimeter2          424 non-null    float64
#  13  area2               424 non-null    float64
#  14  smoothness2         424 non-null    float64
#  15  compactness2        424 non-null    float64
#  16  concavity2          424 non-null    float64
#  17  concave_points2     424 non-null    float64
#  18  symmetry2           424 non-null    float64
#  19  fractal_dimension2  424 non-null    float64
#  20  radius3             424 non-null    float64
#  21  texture3            424 non-null    float64
#  22  perimeter3          424 non-null    float64
#  23  area3               424 non-null    float64
#  24  smoothness3         424 non-null    float64
#  25  compactness3        424 non-null    float64
#  26  concavity3          424 non-null    float64
#  27  concave_points3     424 non-null    float64
#  28  symmetry3           424 non-null    float64
#  29  fractal_dimension3  424 non-null    float64
#  30  labels              424 non-null    object
# dtypes: float64(30), object(1)
# memory usage: 106.0+ KB
# None

# %%
# Encoding the labels with 0 and 1

featuresRaw = data.drop('labels', axis=1)
labelsRaw = data.labels

labelMapping = {}

labelEncoder = LabelEncoder()
labelsEncoded = labelEncoder.fit_transform(labelsRaw)

for class_ in labelEncoder.classes_:
  encoding = labelEncoder.transform([class_])[0]
  labelMapping[encoding] = class_

labels = labelsEncoded
print(labelMapping)
# Out:
# {0: 'B', 1: 'M'}

# %% [markdown]
# ## Splitting Data

# %%
X_train, X_test, y_train, y_test = train_test_split(featuresRaw, labels, test_size=0.3, random_state=42)

trainScaler = StandardScaler()
X_train = trainScaler.fit_transform(X_train)
X_test = trainScaler.transform(X_test)

X_train_df = pd.DataFrame(X_train, columns=featuresRaw.columns)
X_test_df = pd.DataFrame(X_test, columns=featuresRaw.columns)

X_train_df.head()

X_data = np.array(featuresRaw)
y_data = np.array(labels)

# %% [markdown]
# ## Feature Visualization

# %%
# Visualizing the spread of data-points of feature for the two classes. Interesting to observe how they take a guassian shape, and
# gives an intutive sense of how a high-dimensional decision boundarys might separate them.

featuresLabelsDf = copy.deepcopy(X_train_df)
featuresLabelsDf['labels'] = copy.deepcopy(y_train)

col = len(featuresLabelsDf.columns) - 1
num_rows = (col - 1) // 4 + 1
num_cols = min(col, 4)

fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(24, 22))
for i, column in enumerate(featuresLabelsDf.columns[:-1]):
    row = i // num_cols
    col = i % num_cols
    sns.histplot(featuresLabelsDf, x=column, hue='labels', kde=True, multiple='stack', bins=30, ax=axes[row, col])
    axes[row,col].set_title('Distribution of ' + str(column) + ' by Class')
    axes[row,col].set_xlabel(column)
    axes[row,col].set_ylabel('Frequency')
    axes[row,col].legend(title='Class', labels=['Benign', 'Malignant'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Construction and Training

# %%
class LogisticRegression(nn.Module):
  def __init__(self, num_features, l2=0.0):
    super(LogisticRegression, self).__init__()
    self.layer1 = nn.Linear(num_features, 1)
    self.sig = nn.Sigmoid()
    self.l2 = l2


  def forward(self, x):
    out0 = self.layer1(x)
    out1 = self.sig(out0)
    return out1

# %%
# Helper Functions that perform training and reseting of model weights between iteration

def resetWeights(model):
    for layer in model.children():
        if isinstance(layer, nn.Linear):
            layer.reset_parameters()

def trainModelKFold(model, epochs, lossFn, optimizer, X, y, decisionThreshold=0.5, k=1):
    trainAcc, testAcc = np.zeros(epochs), np.zeros(epochs)
    trainErr, testErr = np.zeros(epochs), np.zeros(epochs)
    trainLoss, testLoss = np.zeros(epochs), np.zeros(epochs)

    kf = KFold(n_splits=k, shuffle=True, random_state=42)

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        trainScaler = StandardScaler()
        X_train = trainScaler.fit_transform(X_train)
        X_test = trainScaler.transform(X_test)

        X_train_tensor = torch.tensor(X_train).float()
        X_test_tensor = torch.tensor(X_test).float()
        y_train_tensor = torch.tensor(y_train).float()
        y_test_tensor = torch.tensor(y_test).float()

        resetWeights(model)
        for epoch in range(epochs):
            output = model(X_train_tensor)
            loss = lossFn(output.squeeze(), y_train_tensor)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            with torch.no_grad():
                trainLoss[epoch] += loss.item()
                trainPredictions = (np.array(output.flatten()) > decisionThreshold).astype(int)
                trainError = np.mean(trainPredictions != np.array(y_train_tensor).astype(int))


                output = model(X_test_tensor)
                loss = lossFn(output.squeeze(), y_test_tensor)

                testLoss[epoch] += loss.item()
                testPredictions = (np.array(output.flatten()) > decisionThreshold).astype(int)
                testError = np.mean(testPredictions != np.array(y_test_tensor).astype(int))

                trainErr[epoch] += trainError.item()
                testErr[epoch] += testError.item()
                trainAcc[epoch] += 1 - trainError.item()
                testAcc[epoch] += 1 - testError.item()

    avg_trainAcc = trainAcc/3
    avg_testAcc = testAcc/3
    avg_trainErr = trainErr/3
    avg_testErr = testErr/3
    avg_trainLoss = trainLoss/3
    avg_testLoss = testLoss/3

    return avg_trainAcc, avg_testAcc, avg_trainErr, avg_testErr, avg_trainLoss, avg_testLoss

def trainModel(model, epochs, lossFn, optimizer, X_train, X_test, y_train, y_test, decisionThreshold=0.5):
    trainAcc, testAcc = [], []
    trainErr, testErr = [], []
    trainLoss, testLoss = [], []

    resetWeights(model)
    for epoch in range(epochs):
        output = model(X_train)
        loss = lossFn(output.squeeze(), y_train)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        with torch.no_grad():
            trainLoss.append(loss.item())
            trainPredictions = (np.array(output.flatten()) > decisionThreshold).astype(int)
            trainError = np.mean(trainPredictions != np.array(y_train).astype(int))


            output = model(X_test)
            loss = lossFn(output.squeeze(), y_test)

            testLoss.append(loss.item())
            testPredictions = (np.array(output.flatten()) > decisionThreshold).astype(int)
            testError = np.mean(testPredictions != np.array(y_test).astype(int))

            trainErr.append(trainError.item())
            testErr.append(testError.item())
            trainAcc.append(1 - trainError.item())
            testAcc.append(1 - testError.item())

    return trainAcc, testAcc, trainErr, testErr, trainLoss, testLoss


X_train_tensor = torch.tensor(X_train).float()
y_train_tensor = torch.tensor(y_train).float()
X_test_tensor = torch.tensor(X_test).float()
y_test_tensor = torch.tensor(y_test).float()

# %% [markdown]
# ## Grid Search Analysis

# %%
# Grid search for find the hyperparameter tuning to find best model

epochs_list = [50, 100, 500, 1000]
learning_rates = [1, 0.1, 0.01, 0.001]
momentums = [0, 0.5, 0.9, 0.99]
lambdas = [0, 0.001, 0.01, 0.1, 1]
trainedModels = []

num_features = len(X_train_df.columns)
lossFn = nn.BCELoss()

for lambda_ in lambdas:
  model = LogisticRegression(num_features, l2=lambda_)
  for momentum in momentums:
    for lr in learning_rates:
        optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=model.l2)
        for epochs in epochs_list:
          startTime = time.time()
          trainAcc, testAcc, trainErr, testErr, trainLoss, testLoss = trainModelKFold(
              model,
              epochs,
              lossFn,
              optimizer,
              X_data,
              y_data,
              k=3,
          )
          trainingTime = time.time() - startTime
          trainedModels.append({ 'model': copy.deepcopy(model),
                                'hyperparameters': {'epochs': epochs, 'lr': lr, 'momentum': momentum, 'lambda': lambda_ },
                                'trainingStats': { 'testAcc': testAcc[-1], 'trainAcc': trainAcc[-1],
                                                    'testError': testErr[-1], 'trainError': trainErr[-1],
                                                    'testLoss': testLoss[-1], 'trainLoss': trainLoss[-1] },
                                'trainingTime': trainingTime
                                })
          print(f'Completed epochs, lr, momentum, lambda, test error: {epochs}, {lr}, {momentum}, {lambda_}, --- {testAcc[-1]}')
# Out:
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0, 0, --- 0.971731095794626
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0, 0, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0, 0, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0, 0, --- 0.9623081277261679
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0, 0, --- 0.9504711484034228
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0, 0, --- 0.952868511304232
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0, 0, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0, 0, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0, 0, --- 0.8985948789664703
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0, 0, --- 0.936320047947258
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0, 0, --- 0.941031531981487
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0, 0, --- 0.9622914793726901
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0, 0, --- 0.6437252355742017
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0, 0, --- 0.809076682316119
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0, 0, --- 0.9174408151033863
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0, 0, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.5, 0, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.5, 0, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.5, 0, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.5, 0, --- 0.967019611760397
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.5, 0, --- 0.9599440615323145
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.5, 0, --- 0.96229147937269
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.5, 0, --- 0.9694003263077281
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.5, 0, --- 0.9694003263077281
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.5, 0, --- 0.9103486165218261
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.5, 0, --- 0.9339226850464489
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.5, 0, --- 0.9552159291446075
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.5, 0, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.5, 0, --- 0.7122998035494289
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.5, 0, --- 0.8395265208270902
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.5, 0, --- 0.9221356507841375
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.5, 0, --- 0.9433789498218625
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.9, 0, --- 0.9622914793726901
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.9, 0, --- 0.955265874205041
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.9, 0, --- 0.9623081277261679
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.9, 0, --- 0.9599773582392701
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.9, 0, --- 0.9646888422734992
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.9, 0, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.9, 0, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.9, 0, --- 0.9623081277261679
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.9, 0, --- 0.9457596643691938
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.9, 0, --- 0.957579995338461
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.9, 0, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.9, 0, --- 0.9717477441481037
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.9, 0, --- 0.9221855958445709
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.9, 0, --- 0.9362867512403024
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.9, 0, --- 0.9410481803349647
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.9, 0, --- 0.9457763127226718
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.99, 0, --- 0.9694003263077281
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.99, 0, --- 0.9623247760796456
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.99, 0, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.99, 0, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.99, 0, --- 0.9576632371058502
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.99, 0, --- 0.9646555455665435
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.99, 0, --- 0.9575966436919389
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.99, 0, --- 0.9575966436919389
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.99, 0, --- 0.9599440615323145
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.99, 0, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.99, 0, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.99, 0, --- 0.9623247760796456
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.99, 0, --- 0.9339393333999267
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.99, 0, --- 0.9434122465288183
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.99, 0, --- 0.9623247760796457
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.99, 0, --- 0.9646888422734992
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0, 0.001, --- 0.971731095794626
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0, 0.001, --- 0.9717477441481037
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0, 0.001, --- 0.9717643925015814
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0, 0.001, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0, 0.001, --- 0.9387007624945894
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0, 0.001, --- 0.9528518629507542
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0, 0.001, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0, 0.001, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0, 0.001, --- 0.9079845503279725
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0, 0.001, --- 0.9339559817534046
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0, 0.001, --- 0.9339393333999267
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0, 0.001, --- 0.9528518629507542
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0, 0.001, --- 0.5748509972363732
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0, 0.001, --- 0.8584556987313955
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0, 0.001, --- 0.9269137282322779
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0, 0.001, --- 0.9339393333999267
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.5, 0.001, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.5, 0.001, --- 0.9741118103419572
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.5, 0.001, --- 0.9694003263077281
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.5, 0.001, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.5, 0.001, --- 0.957579995338461
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.5, 0.001, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.5, 0.001, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.5, 0.001, --- 0.9694003263077281
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.5, 0.001, --- 0.9245330136849467
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.5, 0.001, --- 0.9339559817534046
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.5, 0.001, --- 0.957579995338461
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.5, 0.001, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.5, 0.001, --- 0.6884760097226383
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.5, 0.001, --- 0.8797988878899877
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.5, 0.001, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.5, 0.001, --- 0.9362867512403024
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.9, 0.001, --- 0.9599607098857924
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.9, 0.001, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.9, 0.001, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.9, 0.001, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.9, 0.001, --- 0.9623247760796457
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.9, 0.001, --- 0.9646888422734992
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.9, 0.001, --- 0.9717643925015814
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.9, 0.001, --- 0.9694003263077281
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.9, 0.001, --- 0.936320047947258
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.9, 0.001, --- 0.9552325774980854
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.9, 0.001, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.9, 0.001, --- 0.9694003263077281
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.9, 0.001, --- 0.9008923517464122
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.9, 0.001, --- 0.9245163653314687
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.9, 0.001, --- 0.9504877967569008
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.9, 0.001, --- 0.9575799953384609
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.99, 0.001, --- 0.9599440615323145
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.99, 0.001, --- 0.9315919155595512
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.99, 0.001, --- 0.9646888422734992
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.99, 0.001, --- 0.9670529084673526
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.99, 0.001, --- 0.9576632371058502
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.99, 0.001, --- 0.957579995338461
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.99, 0.001, --- 0.9717643925015814
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.99, 0.001, --- 0.9717477441481037
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.99, 0.001, --- 0.952868511304232
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.99, 0.001, --- 0.9670529084673526
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.99, 0.001, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.99, 0.001, --- 0.9694003263077281
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.99, 0.001, --- 0.9316085639130289
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.99, 0.001, --- 0.9410148836280091
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.99, 0.001, --- 0.9623414244331235
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.99, 0.001, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0, 0.01, --- 0.971731095794626
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0, 0.01, --- 0.9433955981753405
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0, 0.01, --- 0.9528352145972763
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0, 0.01, --- 0.9009422968068458
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0, 0.01, --- 0.9268471348183663
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0, 0.01, --- 0.9433955981753405
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0, 0.01, --- 0.952868511304232
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0, 0.01, --- 0.7568175007491759
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0, 0.01, --- 0.5752172610128858
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0, 0.01, --- 0.9364032897146473
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0, 0.01, --- 0.9363366963007359
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.5, 0.01, --- 0.971731095794626
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.5, 0.01, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.5, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.5, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.5, 0.01, --- 0.9481403789165253
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.5, 0.01, --- 0.96229147937269
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.5, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.5, 0.01, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.5, 0.01, --- 0.9174907601638198
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.5, 0.01, --- 0.924483068624513
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.5, 0.01, --- 0.9504877967569008
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.5, 0.01, --- 0.957579995338461
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.5, 0.01, --- 0.7972563513468517
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.5, 0.01, --- 0.8939166916391968
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.5, 0.01, --- 0.9245496620384244
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.5, 0.01, --- 0.9410148836280091
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.9, 0.01, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.9, 0.01, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.9, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.9, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.9, 0.01, --- 0.9646888422734992
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.9, 0.01, --- 0.971731095794626
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.9, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.9, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.9, 0.01, --- 0.9386674657876336
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.9, 0.01, --- 0.9599440615323145
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.9, 0.01, --- 0.971731095794626
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.9, 0.01, --- 0.971731095794626
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.9, 0.01, --- 0.9009922418672794
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.9, 0.01, --- 0.941031531981487
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.9, 0.01, --- 0.9386508174341558
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.9, 0.01, --- 0.957579995338461
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.99, 0.01, --- 0.948157027270003
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.99, 0.01, --- 0.9174075183964305
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.99, 0.01, --- 0.9740951619884793
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.99, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.99, 0.01, --- 0.9600273032997036
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.99, 0.01, --- 0.9386674657876336
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.99, 0.01, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.99, 0.01, --- 0.9693836779542503
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.99, 0.01, --- 0.9623081277261679
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.99, 0.01, --- 0.9623414244331235
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.99, 0.01, --- 0.9646721939200212
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.99, 0.01, --- 0.9670362601138747
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.99, 0.01, --- 0.9363366963007359
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.99, 0.01, --- 0.9528352145972763
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.99, 0.01, --- 0.9646888422734992
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.99, 0.01, --- 0.971731095794626
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0, 0.1, --- 0.9386674657876336
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0, 0.1, --- 0.9457763127226717
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0, 0.1, --- 0.8962308127726167
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0, 0.1, --- 0.9245163653314687
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0, 0.1, --- 0.941031531981487
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0, 0.1, --- 0.9504877967569008
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0, 0.1, --- 0.48651483368294873
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0, 0.1, --- 0.7380381580261712
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0, 0.1, --- 0.9198048812972397
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0, 0.1, --- 0.9268637831718443
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.5, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.5, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.5, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.5, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.5, 0.1, --- 0.9457763127226717
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.5, 0.1, --- 0.9457596643691938
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.5, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.5, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.5, 0.1, --- 0.9386841141411114
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.5, 0.1, --- 0.9339559817534046
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.5, 0.1, --- 0.9434122465288183
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.5, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.5, 0.1, --- 0.8229447607631606
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.5, 0.1, --- 0.9058036160223755
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.5, 0.1, --- 0.919788232943762
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.5, 0.1, --- 0.936320047947258
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.9, 0.1, --- 0.9504711484034228
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.9, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.9, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.9, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.9, 0.1, --- 0.9552325774980854
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.9, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.9, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.9, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.9, 0.1, --- 0.9481403789165253
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.9, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.9, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.9, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.9, 0.1, --- 0.9150767489095329
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.9, 0.1, --- 0.9292112010122199
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.9, 0.1, --- 0.9433789498218627
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.9, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.99, 0.1, --- 0.9410148836280091
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.99, 0.1, --- 0.9457763127226717
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.99, 0.1, --- 0.9434288948822962
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.99, 0.1, --- 0.9504877967569008
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.99, 0.1, --- 0.9010421869277128
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.99, 0.1, --- 0.9104651549961709
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.99, 0.1, --- 0.957579995338461
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.99, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.99, 0.1, --- 0.9576132920454167
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.99, 0.1, --- 0.9434621915892518
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.99, 0.1, --- 0.9457263676622384
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.99, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.99, 0.1, --- 0.9292444977191755
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.99, 0.1, --- 0.9339559817534046
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.99, 0.1, --- 0.952868511304232
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.99, 0.1, --- 0.9481237305630472
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0, 1, --- 0.4552492258515633
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0, 1, --- 0.4552492258515633
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0, 1, --- 0.4552492258515633
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0, 1, --- 0.4552492258515633
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0, 1, --- 0.912662737655246
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0, 1, --- 0.9245163653314687
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0, 1, --- 0.677105184297273
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0, 1, --- 0.8279892118669464
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0, 1, --- 0.9174408151033863
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0, 1, --- 0.9244997169779908
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.5, 1, --- 0.9221356507841375
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.5, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.5, 1, --- 0.9197882329437618
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.5, 1, --- 0.9009090000998902
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.5, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.5, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.5, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.5, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.5, 1, --- 0.9268637831718443
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.5, 1, --- 0.9245163653314687
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.5, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.5, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.5, 1, --- 0.8373955315819265
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.5, 1, --- 0.766240468817634
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.5, 1, --- 0.9245163653314687
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.5, 1, --- 0.9268804315253222
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.9, 1, --- 0.919788232943762
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.9, 1, --- 0.9362701028868244
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.9, 1, --- 0.9268804315253222
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.9, 1, --- 0.910348616521826
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.9, 1, --- 0.9315752672060733
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.9, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 1, 0.99, 1, --- 0.8748876236140246
# Completed epochs, lr, momentum, lambda, test error: 100, 1, 0.99, 1, --- 0.8962141644191389
# Completed epochs, lr, momentum, lambda, test error: 500, 1, 0.99, 1, --- 0.9127293310691572
# Completed epochs, lr, momentum, lambda, test error: 1000, 1, 0.99, 1, --- 0.6451403456198181
# Completed epochs, lr, momentum, lambda, test error: 50, 0.1, 0.99, 1, --- 0.8117071221656178
# Completed epochs, lr, momentum, lambda, test error: 100, 0.1, 0.99, 1, --- 0.9056704291945527
# Completed epochs, lr, momentum, lambda, test error: 500, 0.1, 0.99, 1, --- 0.9339559817534046
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.1, 0.99, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 0.01, 0.99, 1, --- 0.8891719108980123
# Completed epochs, lr, momentum, lambda, test error: 100, 0.01, 0.99, 1, --- 0.9056537808410748
# Completed epochs, lr, momentum, lambda, test error: 500, 0.01, 0.99, 1, --- 0.9245330136849467
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.01, 0.99, 1, --- 0.9292278493656978
# Completed epochs, lr, momentum, lambda, test error: 50, 0.001, 0.99, 1, --- 0.9291945526587421
# Completed epochs, lr, momentum, lambda, test error: 100, 0.001, 0.99, 1, --- 0.9457929610761496
# Completed epochs, lr, momentum, lambda, test error: 500, 0.001, 0.99, 1, --- 0.9339393333999267
# Completed epochs, lr, momentum, lambda, test error: 1000, 0.001, 0.99, 1, --- 0.9292278493656978

# %% [markdown]
# ## Finding the best model that maximizes accuracy using ROC curve:

# %%
def findOptimalThresholdForModelAcc(model, X_test_tensor, y_test_tensor):
  with torch.no_grad(): output = model(X_test_tensor)
  _, _, thresholds = roc_curve(y_test_tensor.detach().numpy(), output.detach().numpy().flatten(), pos_label=1)
  optimalAcc = None
  optimalThreshold = None

  for threshold in thresholds:
    testPredictions = (np.array(output.detach().numpy().flatten()) > threshold).astype(int)
    testAcc = 1 - np.mean(testPredictions != np.array(y_test_tensor).astype(int))
    if (optimalThreshold == None):
      optimalThreshold = threshold
      optimalAcc = testAcc
    elif (testAcc > optimalAcc):
      optimalThreshold = threshold
      optimalAcc = testAcc



  return optimalAcc, optimalThreshold

# %%
globalOptimalModel = None
globalOptimalLoss = None
globalOptimalAcc = None
globalOptimalThreshold = None

for model_ in trainedModels:
    optimalAcc, optimalThreshold = findOptimalThresholdForModelAcc(
        model_['model'],
        X_test_tensor,
        y_test_tensor
    )
    optimalLoss = model_['trainingStats']['testLoss']

    if (globalOptimalLoss == None):
      globalOptimalLoss = optimalLoss
      globalOptimalAcc = optimalAcc
      globalOptimalModel = model_
      globalOptimalThreshold = optimalThreshold
    elif (optimalAcc > globalOptimalAcc):
      globalOptimalLoss = optimalLoss
      globalOptimalAcc = optimalAcc
      globalOptimalModel = model_
      globalOptimalThreshold = optimalThreshold
    elif (optimalAcc == globalOptimalAcc and optimalLoss < globalOptimalLoss):
      globalOptimalLoss = optimalLoss
      globalOptimalAcc = optimalAcc
      globalOptimalModel = model_
      globalOptimalThreshold = optimalThreshold

print(globalOptimalModel)
# Out:
# {'model': LogisticRegression(
#   (layer1): Linear(in_features=30, out_features=1, bias=True)
#   (sig): Sigmoid()
# ), 'hyperparameters': {'epochs': 1000, 'lr': 1, 'momentum': 0.5, 'lambda': 0}, 'trainingStats': {'testAcc': 0.967019611760397, 'trainAcc': 0.9882047298031059, 'testError': 0.0329803882396031, 'trainError': 0.011795270196894135, 'testLoss': 0.11895705262819926, 'trainLoss': 0.0380829373995463}, 'trainingTime': 3.1501784324645996}

# %%
gModel = globalOptimalModel['model']
with torch.no_grad(): output = gModel(X_test_tensor)
fpr, tpr, thresholds = roc_curve(y_test_tensor.detach().numpy(), output.detach().numpy().flatten(), pos_label=1)
rocAUC = auc(fpr, tpr)

plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(rocAUC))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
gLr = globalOptimalModel['hyperparameters']['lr']
gEpochs = globalOptimalModel['hyperparameters']['epochs']
gMomentum = globalOptimalModel['hyperparameters']['momentum']
gLambda = globalOptimalModel['hyperparameters']['lambda']

index = int(np.where(thresholds == globalOptimalThreshold)[0])
FPR = fpr[index]
TPR = tpr[index]

print(f'Global Optimal Model Hyperparameters: lr={gLr}, epochs={gEpochs}, momentum={gMomentum}, lamda={gLambda}')
print(f'Global Optimal TPR: {TPR}, Global Optimal FPR: {FPR}, Global Optimal Threshold: {globalOptimalThreshold}')
print(f'Global Optimal Acc: {globalOptimalAcc}, Global Optimal Loss: {globalOptimalLoss}')
# Out:
# Global Optimal Model Hyperparameters: lr=1, epochs=1000, momentum=0.5, lamda=0
# Global Optimal TPR: 0.9827586206896551, Global Optimal FPR: 0.014285714285714285, Global Optimal Threshold: 0.20634500682353973
# Global Optimal Acc: 0.9921875, Global Optimal Loss: 0.11895705262819926

# %% [markdown]
# ### Reproduceability Test & Visualizing Curves

# %%
lr = globalOptimalModel['hyperparameters']['lr']
epochs = globalOptimalModel['hyperparameters']['epochs']
momentum = globalOptimalModel['hyperparameters']['momentum']
lambda_ = globalOptimalModel['hyperparameters']['lambda']

num_features = len(X_train_df.columns)
model = LogisticRegression(num_features, l2=lambda_)
lossFn = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=model.l2)

trainAcc, testAcc, trainErr, testErr, trainLoss, testLoss = trainModelKFold(
    model,
    epochs,
    lossFn,
    optimizer,
    X_data,
    y_data,
    k=3,
)

model.eval()

plt.plot(trainAcc, label='train accuracy')
plt.plot(testAcc, label='test accuracy')
plt.grid(True)
plt.legend()

plt.figure()
plt.plot(trainErr, label='train error')
plt.plot(testErr, label='test error')
plt.grid(True)
plt.legend()

plt.figure()
plt.plot(trainLoss, label='train loss')
plt.plot(testLoss, label='test loss')
plt.grid(True)
plt.legend()

plt.show()


print(f'Train Accuracy: {trainAcc[-1]}, Train Error: {trainErr[-1]}, Train Loss: {trainLoss[-1]}')
print(f'Test Accuracy: {testAcc[-1]}, Test Error: {testErr[-1]}, Test Loss: {testLoss[-1]}')
# Out:
# Train Accuracy: 0.9882047298031059, Train Error: 0.011795270196894135, Train Loss: 0.037928937623898186
# Test Accuracy: 0.9693836779542503, Test Error: 0.030616322045749673, Test Loss: 0.11918746183315913

# %%
with torch.no_grad(): output = model(X_test_tensor)
fpr, tpr, thresholds = roc_curve(y_test_tensor.detach().numpy(), output.detach().numpy().flatten(), pos_label=1)
rocAUC = auc(fpr, tpr)

plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(rocAUC))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
optimalAcc, optimalThreshold = findOptimalThresholdForModelAcc(
        model,
        X_test_tensor,
        y_test_tensor,
    )

index = int(np.where(thresholds == optimalThreshold)[0])
FPR = fpr[index]
TPR = tpr[index]

print(f'Global Optimal Model Hyperparameters: lr={lr}, epochs={epochs}, momentum={momentum}, lamda={lambda_}')
print(f'Global Optimal TPR: {TPR}, Global Optimal FPR: {FPR}, Global Optimal Threshold: {optimalThreshold}')
print(f'Global Optimal Acc: {optimalAcc}, Global Optimal Loss: {testLoss[-1]}')
# Out:
# Global Optimal Model Hyperparameters: lr=1, epochs=1000, momentum=0.5, lamda=0
# Global Optimal TPR: 0.9827586206896551, Global Optimal FPR: 0.014285714285714285, Global Optimal Threshold: 0.20227296650409698
# Global Optimal Acc: 0.9921875, Global Optimal Loss: 0.11918746183315913

# %% [markdown]
# ## Risk Minimization: Finding the Optimal Model such that it minimizes the risk by increasing true positive rate (TPR)

# %%
def findOptimalThresholdForModel(model, X_test_tensor, y_test_tensor, fprThreshhold=0.25):
  with torch.no_grad(): output = model['model'](X_test_tensor).detach().numpy().flatten()
  fpr, tpr, thresholds = roc_curve(y_test_tensor.detach().numpy(), output, pos_label=1)
  optimalTPR = None
  optimalFPR = None
  optimalThreshold = None

  for threshold in thresholds:
    index = int(np.where(thresholds == threshold)[0])
    FPR = fpr[index]
    TPR = tpr[index]

    if (optimalTPR == None):
      optimalThreshold = threshold
      optimalTPR = TPR
      optimalFPR = FPR
    elif (TPR > optimalTPR and FPR < fprThreshhold):
      optimalThreshold = threshold
      optimalTPR = TPR
      optimalFPR = FPR

    # print(f"Threshold: ---------------------- {threshold}")
    # print(f"True Positive Rate (Sensitivity): {TPR}")
    # print(f"False Positive Rate:              {FPR}")

  return optimalTPR, optimalFPR, optimalThreshold

# %%
globalOptimalModel = None
globalOptimalTPR = None
globalOptimalFPR = None
globalOptimalThreshold = None

for model_ in trainedModels:
    optimalTPR, optimalFPR, optimalThreshold = findOptimalThresholdForModel(
        model_,
        X_test_tensor,
        y_test_tensor
    )

    if (globalOptimalTPR == None):
      globalOptimalTPR = optimalTPR
      globalOptimalFPR = optimalFPR
      globalOptimalModel = model_
      globalOptimalThreshold = optimalThreshold
    elif (optimalTPR > globalOptimalTPR):
      globalOptimalTPR = optimalTPR
      globalOptimalFPR = optimalFPR
      globalOptimalModel = model_
      globalOptimalThreshold = optimalThreshold
    elif (optimalTPR == globalOptimalTPR and optimalFPR < globalOptimalFPR):
      globalOptimalFPR = optimalFPR
      globalOptimalModel = model_
      globalOptimalThreshold = optimalThreshold

print(globalOptimalModel)
# Out:
# {'model': LogisticRegression(
#   (layer1): Linear(in_features=30, out_features=1, bias=True)
#   (sig): Sigmoid()
# ), 'hyperparameters': {'epochs': 500, 'lr': 1, 'momentum': 0.9, 'lambda': 0}, 'trainingStats': {'testAcc': 0.9623081277261679, 'trainAcc': 0.9941023649015529, 'testError': 0.03769187227383212, 'trainError': 0.005897635098447067, 'testLoss': 0.15721154709657034, 'trainLoss': 0.02574467845261097}, 'trainingTime': 1.1084785461425781}

# %%
gModel = globalOptimalModel['model']
with torch.no_grad(): output = gModel(X_test_tensor)
fpr, tpr, thresholds = roc_curve(y_test_tensor.detach().numpy(), output.detach().numpy().flatten(), pos_label=1)
rocAUC = auc(fpr, tpr)

plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(rocAUC))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
gLr = globalOptimalModel['hyperparameters']['lr']
gEpochs = globalOptimalModel['hyperparameters']['epochs']
gMomentum = globalOptimalModel['hyperparameters']['momentum']
gLambda = globalOptimalModel['hyperparameters']['lambda']

with torch.no_grad(): output = gModel(X_test_tensor)
testPredictions = (np.array(output.detach().numpy().flatten()) > globalOptimalThreshold).astype(int)
testError = np.mean(testPredictions != np.array(y_test).astype(int))

print(f'Global Optimal Model Hyperparameters: lr={gLr}, epochs={gEpochs}, momentum={gMomentum}, lamda={gLambda}')
print(f'Global Optimal TPR: {globalOptimalTPR}, Global Optimal FPR: {globalOptimalFPR}, Global Optimal Threshold: {globalOptimalThreshold}')
print(f'Test Accuracy: {1-testError}, Test Error: {testError}')
# Out:
# Global Optimal Model Hyperparameters: lr=1, epochs=500, momentum=0.9, lamda=0
# Global Optimal TPR: 1.0, Global Optimal FPR: 0.0, Global Optimal Threshold: 0.2426232099533081
# Test Accuracy: 0.9921875, Test Error: 0.0078125

# %% [markdown]
# ### Re-produceability Test & Visualization

# %%
lr = globalOptimalModel['hyperparameters']['lr']
epochs = globalOptimalModel['hyperparameters']['epochs']
momentum = globalOptimalModel['hyperparameters']['momentum']
lambda_ = globalOptimalModel['hyperparameters']['lambda']


num_features = len(X_train_df.columns)
model = LogisticRegression(num_features, l2=lambda_)
lossFn = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=model.l2)

trainAcc, testAcc, trainErr, testErr, trainLoss, testLoss = trainModelKFold(
    model,
    epochs,
    lossFn,
    optimizer,
    X_data,
    y_data,
    k=3
)

model.eval()

plt.plot(trainAcc, label='train accuracy')
plt.plot(testAcc, label='test accuracy')
plt.grid(True)
plt.legend()

plt.figure()
plt.plot(trainErr, label='train error')
plt.plot(testErr, label='test error')
plt.grid(True)
plt.legend()

plt.figure()
plt.plot(trainLoss, label='train loss')
plt.plot(testLoss, label='test loss')
plt.grid(True)
plt.legend()

plt.show()


print(f'Train Accuracy: {trainAcc[-1]}, Train Error: {trainErr[-1]}, Train Loss: {trainLoss[-1]}')
print(f'Test Accuracy: {testAcc[-1]}, Test Error: {testErr[-1]}, Test Loss: {testLoss[-1]}')
# Out:
# Train Accuracy: 0.9941023649015529, Train Error: 0.005897635098447067, Train Loss: 0.02541636923948924
# Test Accuracy: 0.9623081277261679, Test Error: 0.03769187227383212, Test Loss: 0.16082991659641266

# %%
with torch.no_grad(): output = model(X_test_tensor)
fpr, tpr, thresholds = roc_curve(y_test_tensor.detach().numpy(), output.detach().numpy().flatten(), pos_label=1)
rocAUC = auc(fpr, tpr)

plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(rocAUC))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
optimalTPR, optimalFPR, optimalThreshold = findOptimalThresholdForModel(
        { 'model': model },
        X_test_tensor,
        y_test_tensor
)

testPredictions = (np.array(output.detach().numpy().flatten()) > optimalThreshold).astype(int)
testError = np.mean(testPredictions != np.array(y_test).astype(int))

print(f'Re: Global Optimal Model Hyperparameters: lr={lr}, epochs={epochs}, momentum={momentum}, lambda={lambda_}')
print(f'Re: Global Optimal TPR: {optimalTPR}, Global Optimal FPR: {optimalFPR}, Global Optimal Threshold: {optimalThreshold}')
print(f'Re: Test Accuracy: {1-testError}, Test Error: {testError}')
# Out:
# Re: Global Optimal Model Hyperparameters: lr=1, epochs=500, momentum=0.9, lambda=0
# Re: Global Optimal TPR: 1.0, Global Optimal FPR: 0.0, Global Optimal Threshold: 0.24393270909786224
# Re: Test Accuracy: 0.9921875, Test Error: 0.0078125

# %% [markdown]
# ## Time Complexity Analysis

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

lambdaValue = 0.001
filteredModels = [modelInfo for modelInfo in trainedModels if modelInfo['hyperparameters']['lambda'] == lambdaValue]

epochsList = [modelInfo['hyperparameters']['epochs'] for modelInfo in filteredModels]
learningRates = [modelInfo['hyperparameters']['lr'] for modelInfo in filteredModels]
momentums = [modelInfo['hyperparameters']['momentum'] for modelInfo in filteredModels]
trainingTimes = [modelInfo['trainingTime'] for modelInfo in filteredModels]

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(epochsList, learningRates, momentums, c=trainingTimes, cmap='viridis', marker='o', s=100)
ax.set_xlabel('Epochs')
ax.set_ylabel('Learning Rate')
ax.set_zlabel('Momentum')
ax.set_title('Training Time Variation with Hyperparameters')
cbar = plt.colorbar(sc)
cbar.set_label('Training Time (seconds)')

plt.show()
